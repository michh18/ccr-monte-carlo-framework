# %%
import yfinance as yf
import pandas as pd

ticker = "AAPL"
start_date = "2020-01-01"

# Download data
data = yf.download(ticker, start=start_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Flatten multi-index columns if they exist
if isinstance(data.columns, pd.MultiIndex):
    data.columns = data.columns.get_level_values(0)  # Keep just the first level

# Reset index so Date becomes a column
data = data.reset_index()

# Keep only the columns you want
data = data[['Date', 'Open', 'High', 'Low', 'Close', 'Volume']]

print(data.head(5))
# Out:
# Price       Date       Open       High        Low      Close     Volume
# 0     2020-01-02  71.476607  72.528589  71.223267  72.468269  135480400
# 1     2020-01-03  71.696144  72.523731  71.539314  71.763702  146322800
# 2     2020-01-06  70.885472  72.374162  70.634539  72.335556  118387200
# 3     2020-01-07  72.345212  72.600968  71.775796  71.995361  108872000
# 4     2020-01-08  71.698589  73.455103  71.698589  73.153503  132079200

# %%
# Save data to price_data.csv
data.to_csv("../data/raw/price_data.csv")
